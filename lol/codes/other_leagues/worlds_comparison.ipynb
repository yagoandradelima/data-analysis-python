# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

w2023 = pd.read_csv("../data/full_data/2023_LoL_esports_match_data_from_OraclesElixir.csv")
# Out:
# C:\Users\yandrade\AppData\Local\Temp\ipykernel_22956\4209552701.py:5: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   w2023 = pd.read_csv("../data/full_data/2023_LoL_esports_match_data_from_OraclesElixir.csv")

# %%
list(w2023.columns)
# Out:
# ['gameid',
#  'datacompleteness',
#  'url',
#  'league',
#  'year',
#  'split',
#  'playoffs',
#  'date',
#  'game',
#  'patch',
#  'participantid',
#  'side',
#  'position',
#  'playername',
#  'playerid',
#  'teamname',
#  'teamid',
#  'champion',
#  'ban1',
#  'ban2',
#  'ban3',
#  'ban4',
#  'ban5',
#  'pick1',
#  'pick2',
#  'pick3',
#  'pick4',
#  'pick5',
#  'gamelength',
#  'result',
#  'kills',
#  'deaths',
#  'assists',
#  'teamkills',
#  'teamdeaths',
#  'doublekills',
#  'triplekills',
#  'quadrakills',
#  'pentakills',
#  'firstblood',
#  'firstbloodkill',
#  'firstbloodassist',
#  'firstbloodvictim',
#  'team kpm',
#  'ckpm',
#  'firstdragon',
#  'dragons',
#  'opp_dragons',
#  'elementaldrakes',
#  'opp_elementaldrakes',
#  'infernals',
#  'mountains',
#  'clouds',
#  'oceans',
#  'chemtechs',
#  'hextechs',
#  'dragons (type unknown)',
#  'elders',
#  'opp_elders',
#  'firstherald',
#  'heralds',
#  'opp_heralds',
#  'void_grubs',
#  'opp_void_grubs',
# ...

# %%
list(w2023["league"].unique())
# Out:
# ['LFL2',
#  'DDH',
#  'EL',
#  'LPL',
#  'GL',
#  'LCKC',
#  'NEXO',
#  'UL',
#  'LVP SL',
#  'LCK',
#  'LFL',
#  'PRM',
#  'LMF',
#  'SL (LATAM)',
#  'VL',
#  'CBLOL',
#  'LEC',
#  'NACL',
#  'LCO',
#  'CBLOLA',
#  'LHE',
#  'NLC',
#  'GLL',
#  'ESLOL',
#  'LLA',
#  'EBL',
#  'TCL',
#  'PGN',
#  'LPLOL',
#  'LCS',
#  'HM',
#  'LJL',
#  'HC',
#  'AL',
#  'PCS',
#  'LDL',
#  'VCS',
#  'EM',
#  'MSI',
#  'LAS',
#  'LRN',
#  'LRS',
#  'EPL',
#  'LJLA',
#  'CT',
#  'WLDs',
#  'ASCI',
#  'CDF',
#  'IC',
#  'USP',
#  'DCup']

# %%
# Selecionar poucas colunas e verificar porque o valor de partidas é 124 e não 110

w2023.head(5)
# Out:
#                   gameid datacompleteness  url league  year   split  playoffs  \
# 0  ESPORTSTMNT06_2753012         complete  NaN   LFL2  2023  Spring         0
# 1  ESPORTSTMNT06_2753012         complete  NaN   LFL2  2023  Spring         0
# 2  ESPORTSTMNT06_2753012         complete  NaN   LFL2  2023  Spring         0
# 3  ESPORTSTMNT06_2753012         complete  NaN   LFL2  2023  Spring         0
# 4  ESPORTSTMNT06_2753012         complete  NaN   LFL2  2023  Spring         0
#
#                   date  game  patch  ...  opp_csat25 golddiffat25 xpdiffat25  \
# 0  2023-01-10 17:07:16     1  13.01  ...       212.0       1356.0      891.0
# 1  2023-01-10 17:07:16     1  13.01  ...       172.0         23.0     -932.0
# 2  2023-01-10 17:07:16     1  13.01  ...       245.0       -264.0    -1191.0
# 3  2023-01-10 17:07:16     1  13.01  ...       220.0        470.0      682.0
# 4  2023-01-10 17:07:16     1  13.01  ...         4.0        -47.0     -476.0
#
# ...

# %%
#w2023 = w2023[(w2023['league'] == "WLDs") & (w2023['datacompleteness'] == "complete")]

# %%
#w2023.index

# %%
#w2023 = w2023.groupby(['gameid']).agg({'kills':'sum', 'deaths':'sum', 'assists':'sum'})

# %%
#w2023

# %%
#w2023.shape[0]
