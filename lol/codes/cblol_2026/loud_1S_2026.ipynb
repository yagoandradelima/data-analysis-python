# %% [markdown]
# ## Análise LOUD 1º Split
# Esse notebook possui como base analisar o que mudou no desempenho da LOUD da primeira fase para os PlayOffs utilizando dados. Ele não procura entender as mudanças de filosofia de decisão dos jogadores, tendo em vista o caráter subjetivo e até a falta de dados para essa informação.
#
# Mas dentro dos dados, o que a LOUD fez menos ou mais para conseguir melhorar seu desempenho? O que dentro do jogo aconteceu? A ideia é tentar tatear a base da informação que indique a tendência do time

# %%
import pandas as pd
import numpy as np

data = pd.read_csv("../../data/full_data/2026_LoL_esports_match_data_from_OraclesElixir.csv")

# %%
# Filtrando apenas as partidas da LOUD
data = data.loc[data["teamname"] == "LOUD"]

# Chamando tail para saber se  os dados estão atualizados
data.tail(3)
# Out:
#                  gameid datacompleteness  url league  year split  playoffs  \
# 12320  LOLTMNT02_349365         complete  NaN  CBLOL  2026   NaN         0
# 12321  LOLTMNT02_349365         complete  NaN  CBLOL  2026   NaN         0
# 12323  LOLTMNT02_349365         complete  NaN  CBLOL  2026   NaN         0
#
#                       date  game  patch  ...  opp_csat25 golddiffat25  \
# 12320  2026-02-08 19:56:27     3  16.03  ...       257.0        975.0
# 12321  2026-02-08 19:56:27     3  16.03  ...        37.0        910.0
# 12323  2026-02-08 19:56:27     3  16.03  ...       963.0       3666.0
#
#       xpdiffat25 csdiffat25 killsat25 assistsat25 deathsat25  opp_killsat25  \
# 12320     1396.0       -3.0       5.0         1.0        0.0            3.0
# 12321      266.0       10.0       0.0         7.0        2.0            0.0
# 12323     7598.0       70.0       8.0        14.0        6.0            6.0
#
#       opp_assistsat25 opp_deathsat25
# ...

# %%
# Verificando se existe uma forma de distinguir os playoffs através da coluna "playoffs"
data["playoffs"].unique()
# Out:
# array([0])

# %%
data = data.drop(["split","playoffs","url"],axis=1)

# %%
for column in data.columns:
    print(column)
# Out:
# gameid
# datacompleteness
# league
# year
# date
# game
# patch
# participantid
# side
# position
# playername
# playerid
# teamname
# teamid
# firstPick
# champion
# ban1
# ban2
# ban3
# ban4
# ban5
# pick1
# pick2
# pick3
# pick4
# pick5
# gamelength
# result
# kills
# deaths
# assists
# teamkills
# teamdeaths
# doublekills
# triplekills
# quadrakills
# pentakills
# firstblood
# firstbloodkill
# firstbloodassist
# firstbloodvictim
# team kpm
# ckpm
# firstdragon
# dragons
# opp_dragons
# elementaldrakes
# opp_elementaldrakes
# infernals
# mountains
# clouds
# oceans
# chemtechs
# hextechs
# dragons (type unknown)
# elders
# opp_elders
# firstherald
# heralds
# opp_heralds
# void_grubs
# opp_void_grubs
# firstbaron
# barons
# opp_barons
# atakhans
# opp_atakhans
# firsttower
# towers
# opp_towers
# firstmidtower
# firsttothreetowers
# turretplates
# opp_turretplates
# inhibitors
# opp_inhibitors
# damagetochampions
# dpm
# damageshare
# damagetakenperminute
# ...

# %%
for i in data.loc[:,"dragons":"barons"]:
    print(f"{i} - {data[i].isna().sum()}")
# Out:
# dragons - 60
# opp_dragons - 60
# elementaldrakes - 60
# opp_elementaldrakes - 60
# infernals - 60
# mountains - 60
# clouds - 60
# oceans - 60
# chemtechs - 60
# hextechs - 60
# dragons (type unknown) - 72
# elders - 60
# opp_elders - 60
# firstherald - 60
# heralds - 60
# opp_heralds - 60
# void_grubs - 60
# opp_void_grubs - 60
# firstbaron - 60
# barons - 0

# %%
data[data.loc[:,"dragons":"barons"].notna()]
# Out:
#       gameid datacompleteness league  year date  game  patch  participantid  \
# 1884     NaN              NaN    NaN   NaN  NaN   NaN    NaN            NaN
# 1885     NaN              NaN    NaN   NaN  NaN   NaN    NaN            NaN
# 1886     NaN              NaN    NaN   NaN  NaN   NaN    NaN            NaN
# 1887     NaN              NaN    NaN   NaN  NaN   NaN    NaN            NaN
# 1888     NaN              NaN    NaN   NaN  NaN   NaN    NaN            NaN
# ...      ...              ...    ...   ...  ...   ...    ...            ...
# 12318    NaN              NaN    NaN   NaN  NaN   NaN    NaN            NaN
# 12319    NaN              NaN    NaN   NaN  NaN   NaN    NaN            NaN
# 12320    NaN              NaN    NaN   NaN  NaN   NaN    NaN            NaN
# 12321    NaN              NaN    NaN   NaN  NaN   NaN    NaN            NaN
# 12323    NaN              NaN    NaN   NaN  NaN   NaN    NaN            NaN
#
# ...

# %%
data["clouds"][data["clouds"].notna()]
# Out:
# 1894     0.0
# 2218     2.0
# 4691     0.0
# 5003     0.0
# 5074     0.0
# 8170     0.0
# 8878     0.0
# 11650    0.0
# 11687    0.0
# 12251    0.0
# 12299    0.0
# 12323    3.0
# Name: clouds, dtype: float64

# %%
# unique() retorna um ndarray e para contar a quantidade de elementos eu utilizei o .size
data["gameid"].unique().size
# Out:
# 12
