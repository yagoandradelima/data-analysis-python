# %%
import pandas as pd
import numpy as np

ages = [18, 20, 21, 27, 24, 31, 37, 45, 48, 52, 55, 62, 67, 71]

bins = [18, 25, 35, 60, 100]

age_categories = pd.cut(ages, bins)

# %%
age_categories
# Out:
# [NaN, (18.0, 25.0], (18.0, 25.0], (25.0, 35.0], (18.0, 25.0], ..., (35, 60], (35, 60], (60, 100], (60, 100], (60, 100]]
# Length: 14
# Categories (4, interval[int64, right]): [(18, 25] < (25, 35] < (35, 60] < (60, 100]]

# %%
age_categories.codes
# Out:
# array([-1,  0,  0,  1,  0,  1,  2,  2,  2,  2,  2,  3,  3,  3], dtype=int8)
